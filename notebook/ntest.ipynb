# %%
import great_expectations as ge

context = ge.get_context()

batch_request = {"datasource_name":"taxi_pandas","data_connector_name":"monthly","data_asset_name":"reports"}
onboarding_results = context.assistants.onboarding.run(batch_request)
# Out:
# ---------------------------------------------------------------------------
# DatasourceError                           Traceback (most recent call last)
# c:\cdf-poc\centraal-dataframework\notebook\ntest.ipynb Cell 1 line 6
#       <a href='vscode-notebook-cell:/c%3A/cdf-poc/centraal-dataframework/notebook/ntest.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> context = ge.get_context()
#       <a href='vscode-notebook-cell:/c%3A/cdf-poc/centraal-dataframework/notebook/ntest.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> batch_request = {"datasource_name":"taxi_pandas","data_connector_name":"monthly","data_asset_name":"reports"}
# ----> <a href='vscode-notebook-cell:/c%3A/cdf-poc/centraal-dataframework/notebook/ntest.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> onboarding_results = context.assistants.onboarding.run(batch_request)
#
# ...
